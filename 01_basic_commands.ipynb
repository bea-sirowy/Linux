# %% [markdown]
# Beata Sirowy
#
# # Linux basics

# %% [markdown]
# ## __Basic commands__

# %% [markdown]
# ### __Changing keyboard layout__

# %%
setxkbmap -layout no

setxkbmap -layout en

setxkbmap -layout us

# %% [markdown]
# ### __Finding yourself with pwd__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Getting root access__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Checking your user name with whoami__

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### __Changing directories with cd__
#
# cd /[the name of the directory]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To move up one level we use cd ..

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To move up more than one level, use multiple double-dot pairs
#
# cd .. ..
#
# cd .. .. ..

# %% [markdown]
# To move up to the root level in the file structure entering cd /

# %% [markdown]
# ### __Viewing the content of a directory with ls__

# %% [markdown]
# To see the content of a directory use ls (similar to dir command in windows)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To get more info about the directories use ls -l (long listing)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To view the hidden files type ls -la

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Accessing help__
#
# To access help on a given tool - e.g. aircrack-ng - type  --help

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Other options to access help: -h  or -?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Most commands have a manual (man) page with more info. To access it type man
#
# e.g.
# man python
#
# man grep

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To exit: type q

# %% [markdown]
# To find an instance of a given string type locate
# e.g. locate aircrack-ng

# %% [markdown]
# If you are looking for a binary file you can use whereis
#
# eg. whereis aircrack-ng

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To find the path of a file type which
# e.g. which aircrack-ng

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Performing more powerful searches with find:
#
# find _directory options expressions_

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Processes running on the machine__

# %% [markdown]
# To check the processes use the command ps aux

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can further filter this using grep command
#
# ps aux | grep python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## __Modifying files and directories__

# %% [markdown]
# ### __Creating files with cat__

# %% [markdown]
# - cat command (short for concatenate): usually used for displaying the contents of a file but can be used to create small files
#
# - for bigger files it is better to enter the code in a text editor - vim, emacs, leafpad, gedit, kate etc
#
# - cat [filename] will display the content of a file
#
# - cat > [a name for the file to be created] creates a new file
# - use CTRL + D to stop writing content into a file

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# we use cat >> to __append more content to a file__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# to overvrite a file with new info use cat command with a single redirect again

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### __Creating files with touch__
#
# touch [filename]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can write content to the file using cat command

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Creating a directory__

# %% [markdown]
# mkdir [directory_name]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Copying a file__

# %% [markdown]
# cp [filename] [destination]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can also rename the file in the process

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Renaming a file__

# %% [markdown]
# We use the mv command to move a file or a directory to a new location or to give the existing file or a directory a new name

# %% [markdown]
# mv [oldname] [newname]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Removing a file__

# %% [markdown]
# rm [filename]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### __Removing a directory__

# %% [markdown]
# rmdir[directory_name]
#
# - This command will only remove the directory when it is empty

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can delete the files and try again

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __To remove a directory and its contents with one command:__
#
# rm -r [directory_name]

# %% [markdown]
# ![image.png](attachment:image.png)
