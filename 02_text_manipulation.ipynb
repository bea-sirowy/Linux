# %% [markdown]
# Beata Sirowy
#
# # Linux: text manipulation

# %% [markdown]
# ### Accessing the file content

# %% [markdown]
# cat [filepath]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Taking the head

# %% [markdown]
# By default we get the first ten lines with the command
#
# head [filepath]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can specify the number of lines
#
# e.g. head -20 [filepath]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Getting the tail

# %% [markdown]
# tail [filepath]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Numbering the lines

# %% [markdown]
# nl [filepath]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Filtering text with grep

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  Using tail and head to isolate specific lines

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Using sed to find and replace a string, making a copy of the file with the replaced string

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can change the string in the entire document adding a parameter g (global)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can also change a specific occurence of a string - specifying the number instead of g

# %% [markdown]
# ### Controlling the display with more

# %% [markdown]
# ![image.png](attachment:image.png)
